# %% [markdown]
# # 필요한 라이브러리 설치 (Python 3.9)

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import json
import re

from sklearn.model_selection import train_test_split
from keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense,Flatten,Embedding
import pickle


print(tf.__version__) # 2.11.0
# Out:
# 2.11.0

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ---

# %%
def clean_text(text):
    # 한글과 공백만 남기고 나머지 문자 제거
    cleaned_text = re.sub(r'[^가-힣\s]', '', text)
    return cleaned_text.strip()

# %%
def load_data(data_name):
    """
    input: (str)
    => data_name: name of raw text csv
    """
    data = pd.read_csv(data_name,encoding='utf-8', index_col=0)

    data = data[~data['text'].str.match('^\d+$')]
    data = data[~data['text'].str.contains('\u200b')]
    
    data['text'] = data['text'].apply(clean_text)
    data = data[data['text'] != '']
    data.reset_index(drop=True, inplace=True)

    return data

data_name = "file-name.csv'
data = load_data(data_name)
docs = data['text']
classes = data['label']
data
# Out:
#                                                    text  label     website
# 0                                                 남은 시간      5        11st
# 1                                                    리뷰      5        11st
# 2                                                     개      5        11st
# 3                                                   종 택      5        11st
# 4                                       팩 외 팩 김나운 진꼬리곰탕      5        11st
# ...                                                 ...    ...         ...
# 6732                                                 반품      5  temu_home2
# 6733                                               문의하기      5  temu_home2
# 6734                                            테무 홈페이지      5  temu_home2
# 6735                                                판매됨      6  temu_home2
# 6736  걸 수 있는 흔적 없는 개 세트 후크  캐주얼한 스타일의 플라스틱 다용도 후크 세트 열쇠      5  temu_home2
#
# [6737 rows x 3 columns]

# %%
# 데이터프레임에서 텍스트와 라벨 열 분리
docs = data['text']
classes = data['label']

# train / test 분할 (80% Train, 20% Test)
X_train, X_test, y_train, y_test = train_test_split(docs, classes, test_size=0.2, random_state=42)
y_train_one_hot = pd.get_dummies(y_train)

# %%
def preprocessing(text):
    """
    input: (pandas.Series.series or list)
    output: (tokenizer, padded_X)
    """
    token = Tokenizer()
    token.fit_on_texts(text)
    x = token.texts_to_sequences(text)
    padded_x = pad_sequences(x, 16)
    return token, padded_x

token, padded_x = preprocessing(X_train)

# %%
# tokenizer 객체를 저장
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(token, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # 모델 빌드 & 훈련

# %% [markdown]
# ----

# %%
def make_model(padded_x, y_train):
    y_train_one_hot = pd.get_dummies(y_train)
    model = Sequential()
    model.add(Embedding(input_dim=max(padded_x.flatten())+1, output_dim=16, input_length=16))
    model.add(Dense(16, activation='relu'))
    model.add(Flatten())
    model.add(Dense(2, activation='sigmoid'))

    model.compile(optimizer='adam', 
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
    epochs = 10
    model.fit(
        padded_x,
        y_train_one_hot,
        epochs=epochs)

    return model

model = make_model(padded_x, y_train)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 16, 16)            97392
#
#  dense_4 (Dense)             (None, 16, 16)            272
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 98,692
# Trainable params: 98,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
history = model.fit(
    padded_x,
    y_train_one_hot,
    epochs=epochs)
# Out:
# Epoch 1/100
# 169/169 [==============================] - 2s 4ms/step - loss: 0.4964 - accuracy: 0.9187
# Epoch 2/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1674 - accuracy: 0.9531
# Epoch 3/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0670 - accuracy: 0.9887
# Epoch 4/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0418 - accuracy: 0.9898
# Epoch 5/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0297 - accuracy: 0.9915
# Epoch 6/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0229 - accuracy: 0.9929
# Epoch 7/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0184 - accuracy: 0.9942
# Epoch 8/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9952
# Epoch 9/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0138 - accuracy: 0.9957
# Epoch 10/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0125 - accuracy: 0.9954
# Epoch 11/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0109 - accuracy: 0.9967
# Epoch 12/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0102 - accuracy: 0.9968
# Epoch 13/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0093 - accuracy: 0.9968
# Epoch 14/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0086 - accuracy: 0.9976
# Epoch 15/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0078 - accuracy: 0.9980
# Epoch 16/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0071 - accuracy: 0.9980
# Epoch 17/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0066 - accuracy: 0.9981
# Epoch 18/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0062 - accuracy: 0.9981
# Epoch 19/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0062 - accuracy: 0.9978
# Epoch 20/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 21/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 22/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.9983
# Epoch 23/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0050 - accuracy: 0.9985
# Epoch 24/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 25/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0048 - accuracy: 0.9983
# Epoch 26/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 27/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 28/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9980
# Epoch 29/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 30/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 31/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 32/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 33/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 34/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9985
# Epoch 35/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 36/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 37/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 38/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0042 - accuracy: 0.9989
# Epoch 39/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 40/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 41/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 42/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 43/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9989
# Epoch 44/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 45/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 46/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 47/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9989
# Epoch 48/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 49/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 50/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 51/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 52/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9985
# Epoch 53/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 54/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 55/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 56/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 57/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 58/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 59/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 60/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 61/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 62/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 63/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 64/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 65/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 66/100
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 67/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 68/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 69/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 70/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 71/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 72/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 73/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0029 - accuracy: 0.9989
# Epoch 74/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 75/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 76/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0026 - accuracy: 0.9989
# Epoch 77/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9985
# Epoch 78/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 79/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 80/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 81/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 82/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 83/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 84/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 85/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 86/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 87/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 88/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 89/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 90/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 91/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 92/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 93/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 94/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0028 - accuracy: 0.9989
# Epoch 95/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 96/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9985
# Epoch 97/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 98/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 99/100
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 100/100
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0030 - accuracy: 0.9989

# %%
# 테스트 세트에 대해서도 전처리하고 패딩
def pre_pad(X_train, token):
    x = token.texts_to_sequences(X_train)
    padded_x = pad_sequences(x, 16)
    return padded_x

def pre_y(y_train):
    y_train_one_hot = pd.get_dummies(y_train)
    return y_train_one_hot

X_test_pad = pre_pad(X_test, token)
y_test_one_hot = pre_y(y_test)

# %%
print("\n Accuracy: %.4f" % (model.evaluate(X_test_pad, y_test_one_hot)[1]))
# Out:
# 43/43 [==============================] - 1s 4ms/step - loss: 0.0586 - accuracy: 0.9918
#
#  Accuracy: 0.9918

# %% [markdown]
# # 예측하기

# %%
def load_json(json_name):
    
    with open(json_name, "r", encoding ='utf-8') as f:
        data_json = json.load(f)
    
    texts = [item['text'] for item in data_json]
    xpaths = [item['xpath'] for item in data_json]
    
    data = pd.DataFrame({
        'text': texts,
        'xpath': xpaths
    })
    return data

json_name = "file-name"
data2 = load_json(json_name)
data2
# Out:
#                                                    text  \
# 0     <iframe src="https://www.googletagmanager.com/...
# 1     이 어플리케이션을 보려면 자바스크립트를 활성화해야 합니다. <img height="...
# 2                                                  마트직송
# 3                                                  마트직송
# 4                                                  즉시배송
# ...                                                 ...
# 2269                                               배송시간
# 2270                                                  홈
# 2271                                              마이페이지
# 2272                                               자주구매
# 2273                                            상단으로 이동
#
#                                                   xpath
# 0                                   /html/body/noscript
# 1                                /html/body/noscript[2]
# 2       /html/body/div/div/div/header/div/div[2]/div/h2
# 3     /html/body/div/div/div/header/div/div[2]/div/b...
# 4     /html/body/div/div/div/header/div/div[2]/div/b...
# ...                                                 ...
# 2269             /html/body/div/div/nav/div/button[2]/p
# 2270             /html/body/div/div/nav/div/button[3]/p
# 2271             /html/body/div/div/nav/div/button[4]/p
# 2272             /html/body/div/div/nav/div/button[5]/p
# 2273              /html/body/div/div/div[3]/button/span
#
# [2274 rows x 2 columns]

# %%
def print_prediction(model, padded_docs, docs):
    """
    Print the prediciton of padded data
    """
    predictions = model.predict(padded_docs)

    predicted_classes = np.argmax(predictions, axis=1)

    # 다크패턴인 문구만 출력
    for i, label in enumerate(predicted_classes):
        if label != 0:
            original_text = docs.iloc[i]  
            print(f"Predicted label of Sample {i}: {label}, Original text: {original_text},")

# %%
# Predict label 
docs2 = data2['text']
test_token = token.texts_to_sequences(docs2)
padded_docs = pad_sequences(test_token, 16)
print_prediction(model, padded_docs, docs2)
# Out:
# 72/72 [==============================] - 0s 4ms/step
# Predicted label of Sample 37: 2, Original text: 최저가 도전,
# Predicted label of Sample 113: 1, Original text: 함께할인,
# Predicted label of Sample 146: 1, Original text: 함께할인,
# Predicted label of Sample 331: 1, Original text: 함께할인,
# Predicted label of Sample 1904: 1, Original text: 함께할인,
# Predicted label of Sample 1924: 2, Original text: 함께할인 상품선택,

# %%
#Save model as .h5
model.save('clf_model.h5')

# %% [markdown]
# ------
